# %%
import os
os.chdir("..")

# %%
from src.train import Train

# %%
t = Train()

# %%
t.main()
# Out:
# 2024-06-19 17:27:35.930 | INFO     | src.train:main:153 - Starting Train pipeline
# 2024-06-19 17:27:35.931 | INFO     | src.train:load_data:29 - Loading input data
# 2024-06-19 17:27:35.934 | INFO     | src.train:load_data:35 - Input data loaded
# 2024-06-19 17:27:35.935 | INFO     | src.train:train_test_split:39 - Splitting the dataset.
# 2024-06-19 17:27:35.937 | INFO     | src.train:train_test_split:46 - Dataset splitted into train and test.
# 2024-06-19 17:27:35.980 | INFO     | src.train:train_test_split:49 - Datasets saved to local directory.
# 2024-06-19 17:27:35.981 | INFO     | src.train:resample_train_data:52 - Oversampling train set.
# 2024-06-19 17:27:35.999 | INFO     | src.train:resample_train_data:59 - Train set oversampled.
# 2024-06-19 17:27:36.006 | INFO     | model:init_model:21 - Initializing model 🤖
# 2024-06-19 17:27:36.012 | INFO     | model:init_model:26 - Model Initialized ✅
# ...

# %%
t.preprocessor
# Out:
# ColumnTransformer(transformers=[('Imputer',
#                                  SimpleImputer(fill_value=0,
#                                                strategy='constant'),
#                                  ['GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%',
#                                   '3P Made', '3PA', '3P%', 'FTM', 'FTA', 'FT%',
#                                   'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#                                   'TOV']),
#                                 ('Scaling', StandardScaler(),
#                                  ['GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%',
#                                   '3P Made', '3PA', '3P%', 'FTM', 'FTA', 'FT%',
#                                   'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#                                   'TOV'])])

# %%
t.preprocessor.get_feature_names_out()
# Out:
# array(['Imputer__GP', 'Imputer__MIN', 'Imputer__PTS', 'Imputer__FGM',
#        'Imputer__FGA', 'Imputer__FG%', 'Imputer__3P Made', 'Imputer__3PA',
#        'Imputer__3P%', 'Imputer__FTM', 'Imputer__FTA', 'Imputer__FT%',
#        'Imputer__OREB', 'Imputer__DREB', 'Imputer__REB', 'Imputer__AST',
#        'Imputer__STL', 'Imputer__BLK', 'Imputer__TOV', 'Scaling__GP',
#        'Scaling__MIN', 'Scaling__PTS', 'Scaling__FGM', 'Scaling__FGA',
#        'Scaling__FG%', 'Scaling__3P Made', 'Scaling__3PA', 'Scaling__3P%',
#        'Scaling__FTM', 'Scaling__FTA', 'Scaling__FT%', 'Scaling__OREB',
#        'Scaling__DREB', 'Scaling__REB', 'Scaling__AST', 'Scaling__STL',
#        'Scaling__BLK', 'Scaling__TOV'], dtype=object)

# %%
t.model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
t.train_pipe
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Imputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['GP', 'MIN', 'PTS', 'FGM',
#                                                    'FGA', 'FG%', '3P Made',
#                                                    '3PA', '3P%', 'FTM', 'FTA',
#                                                    'FT%', 'OREB', 'DREB', 'REB',
#                                                    'AST', 'STL', 'BLK',
#                                                    'TOV']),
#                                                  ('Scaling', StandardScaler(),
#                                                   ['GP', 'MIN', 'PTS', 'FGM',
#                                                    'FGA', 'FG%', '3P Made',
# ...
